# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Problem-Statement:" data-toc-modified-id="Problem-Statement:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Problem Statement:</a></span></li><li><span><a href="#Importing-Packages" data-toc-modified-id="Importing-Packages-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Importing Packages</a></span></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Visualizing-Feature-Distributions" data-toc-modified-id="Visualizing-Feature-Distributions-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Visualizing Feature Distributions</a></span></li><li><span><a href="#Exploring-the-Financial-Quarterly-Trends" data-toc-modified-id="Exploring-the-Financial-Quarterly-Trends-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Exploring the Financial Quarterly Trends</a></span><ul class="toc-item"><li><span><a href="#Q3-2018----July-1,-2018-to-September-30,-2018" data-toc-modified-id="Q3-2018----July-1,-2018-to-September-30,-2018-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Q3 2018 -- July 1, 2018 to September 30, 2018</a></span></li><li><span><a href="#Q4-2018----October-1,-2018-to-December-31,-2018" data-toc-modified-id="Q4-2018----October-1,-2018-to-December-31,-2018-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Q4 2018 -- October 1, 2018 to December 31, 2018</a></span></li><li><span><a href="#Q1-2019----January-1,-2019-to-March-31,-2019" data-toc-modified-id="Q1-2019----January-1,-2019-to-March-31,-2019-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Q1 2019 -- January 1, 2019 to March 31, 2019</a></span></li><li><span><a href="#Q2-2019----April-1,-2019-to-June-30,-2019" data-toc-modified-id="Q2-2019----April-1,-2019-to-June-30,-2019-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>Q2 2019 -- April 1, 2019 to June 30, 2019</a></span></li><li><span><a href="#Q3-2019----July-1,-2019-to-September-30,-2019" data-toc-modified-id="Q3-2019----July-1,-2019-to-September-30,-2019-3.2.5"><span class="toc-item-num">3.2.5&nbsp;&nbsp;</span>Q3 2019 -- July 1, 2019 to September 30, 2019</a></span><ul class="toc-item"><li><span><a href="#Q3-2019-Stats-VS-Q3-2018-Stats" data-toc-modified-id="Q3-2019-Stats-VS-Q3-2018-Stats-3.2.5.1"><span class="toc-item-num">3.2.5.1&nbsp;&nbsp;</span>Q3 2019 Stats VS Q3 2018 Stats</a></span></li></ul></li><li><span><a href="#Q4-2019----October-1,-2019-to-December-31,-2019" data-toc-modified-id="Q4-2019----October-1,-2019-to-December-31,-2019-3.2.6"><span class="toc-item-num">3.2.6&nbsp;&nbsp;</span>Q4 2019 -- October 1, 2019 to December 31, 2019</a></span><ul class="toc-item"><li><span><a href="#Q4-2019-Stats-VS-Q4-2018-Stats" data-toc-modified-id="Q4-2019-Stats-VS-Q4-2018-Stats-3.2.6.1"><span class="toc-item-num">3.2.6.1&nbsp;&nbsp;</span>Q4 2019 Stats VS Q4 2018 Stats</a></span></li></ul></li></ul></li><li><span><a href="#Exploring-Quarterly-Stats" data-toc-modified-id="Exploring-Quarterly-Stats-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Exploring Quarterly Stats</a></span><ul class="toc-item"><li><span><a href="#Q2-2019-Stats-VS-Q1-2019-Stats" data-toc-modified-id="Q2-2019-Stats-VS-Q1-2019-Stats-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Q2 2019 Stats VS Q1 2019 Stats</a></span></li><li><span><a href="#Q2-2019-Stats-VS-Q1-2019-Stats" data-toc-modified-id="Q2-2019-Stats-VS-Q1-2019-Stats-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Q2 2019 Stats VS Q1 2019 Stats</a></span></li></ul></li><li><span><a href="#Daily-Gross-Sales-Correlation-Heatmap" data-toc-modified-id="Daily-Gross-Sales-Correlation-Heatmap-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Daily Gross Sales Correlation Heatmap</a></span></li><li><span><a href="#Daily-Gross-Sales-(in-thousands)" data-toc-modified-id="Daily-Gross-Sales-(in-thousands)-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Daily Gross Sales (in thousands)</a></span></li></ul></li><li><span><a href="#ACF-&amp;-PACF-Plots" data-toc-modified-id="ACF-&amp;-PACF-Plots-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>ACF &amp; PACF Plots</a></span></li><li><span><a href="#ADF-Test-for-Stationarity" data-toc-modified-id="ADF-Test-for-Stationarity-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>ADF Test for Stationarity</a></span></li><li><span><a href="#Model-Prep" data-toc-modified-id="Model-Prep-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Model Prep</a></span></li><li><span><a href="#Model-Selection-with-AIC:" data-toc-modified-id="Model-Selection-with-AIC:-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Model Selection with AIC:</a></span></li><li><span><a href="#Modeling" data-toc-modified-id="Modeling-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Modeling</a></span></li><li><span><a href="#Model-Evaluation" data-toc-modified-id="Model-Evaluation-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Model Evaluation</a></span><ul class="toc-item"><li><span><a href="#Baseline-Model" data-toc-modified-id="Baseline-Model-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Baseline Model</a></span></li><li><span><a href="#r2-Metric-Score" data-toc-modified-id="r2-Metric-Score-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>r2 Metric Score</a></span></li><li><span><a href="#RMSE-Metric-Score" data-toc-modified-id="RMSE-Metric-Score-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>RMSE Metric Score</a></span></li><li><span><a href="#Residuals-Plot" data-toc-modified-id="Residuals-Plot-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>Residuals Plot</a></span></li><li><span><a href="#Sales-Predictions-SARIMAX-Graph" data-toc-modified-id="Sales-Predictions-SARIMAX-Graph-9.5"><span class="toc-item-num">9.5&nbsp;&nbsp;</span>Sales Predictions SARIMAX Graph</a></span></li></ul></li><li><span><a href="#Budget-Calculations" data-toc-modified-id="Budget-Calculations-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Budget Calculations</a></span><ul class="toc-item"><li><span><a href="#The-Bible:" data-toc-modified-id="The-Bible:-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>The Bible:</a></span></li></ul></li><li><span><a href="#Conclusion-&amp;-Reccomendations" data-toc-modified-id="Conclusion-&amp;-Reccomendations-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Conclusion &amp; Reccomendations</a></span></li><li><span><a href="#References" data-toc-modified-id="References-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>References</a></span></li></ul></div>

# %% [markdown]
# ## Problem Statement:

# %% [markdown]
# I am a consultant hired by restaurant owners, since new management has taken over their costs have gone through the roof and now they are 25K in the red on average each month. In order for them to recoup their loss I need to figure out how to properly structure their budgets. I will create a SARIMAX predictive sales model to base my customized bugets from. My metric will be RMSE to gauge my model with because the output will be on the same scale as my data. A succesful model will output predictive sales values within a $500.00 range.

# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.model_selection import train_test_split
from statsmodels.tsa.statespace.sarimax import SARIMAX
# Import ARIMA model.
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import seaborn as sns
# Import Augmented Dickey-Fuller test.
from statsmodels.tsa.stattools import adfuller
from sklearn import metrics
from sklearn.metrics import mean_squared_error

from os import listdir
from os.path import isfile, join

import math

# %matplotlib inline

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

import itertools

import warnings
warnings.filterwarnings("ignore")

# %%
def data_reader_cleaner(folder_path):
    data_file_csv = [f for f in listdir(folder_path) if isfile(join(folder_path, f)) & f.endswith('.csv')]
    df = pd.DataFrame()
    for file_path in data_file_csv:
        # 1) read in csv
        data = pd.read_csv(folder_path + file_path)
        # 2) reset_index
        data.reset_index(inplace=True)
        # 3)set colunms as row 0 
        data.columns = data.iloc[0]
        # 4) drop first and last columns
        data.drop([0, len(data)-1], axis = 0, inplace = True)
        # 5) set index as date
        data.set_index('Date', inplace = True) 
        # 6) Print out if nulls
        if data.isnull().sum().sum() > 0:
            data.isnull().sum().sort_values(ascending = False)         
        #  ) concats
        df = pd.concat([data,df])
    return df
merge = data_reader_cleaner('./data/')
merge
# Out:
# 0          Day of the Week Bill Count    Voids Gross Sales Discounts  \
# Date
# 2020-01-01       Wednesday         67   $52.00   $3,687.00    $51.00
# 2020-01-02        Thursday         57   $55.00   $3,171.00     $0.00
# 2020-01-03          Friday         78   $97.50   $4,416.00     $0.00
# 2020-01-04        Saturday        132  $312.00   $6,946.00    $38.50
# 2020-01-05          Sunday        103   $82.00   $5,821.00     $0.00
# ...                    ...        ...      ...         ...       ...
# 2018-12-27        Thursday         76   $89.00   $4,706.00     $6.60
# 2018-12-28          Friday         82  $100.00   $4,895.00    $10.00
# 2018-12-29        Saturday        111  $124.00   $6,307.00     $0.00
# 2018-12-30          Sunday         94  $227.00   $5,393.00    $10.10
# 2018-12-31          Monday         72  $123.00   $4,845.00     $0.00
#
# 0           Net Sales Menu Item Cost Labor Cost     Margin
# Date
# 2020-01-01  $3,636.00         $36.00  $1,166.20  $2,433.80
# 2020-01-02  $3,171.00          $0.00  $1,002.53  $2,168.47
# 2020-01-03  $4,416.00        $154.00  $1,413.91  $2,848.09
# 2020-01-04  $6,907.50         $24.00  $1,697.33  $5,186.17
# 2020-01-05  $5,821.00         $58.00  $1,514.09  $4,248.91
# ...               ...            ...        ...        ...
# 2018-12-27  $4,699.40        $114.00    $696.53  $3,888.87
# 2018-12-28  $4,885.00         $72.00    $833.36  $3,979.64
# 2018-12-29  $6,307.00        $212.00  $1,244.73  $4,850.27
# 2018-12-30  $5,382.90         $48.00  $1,142.10  $4,192.80
# 2018-12-31  $4,845.00         $84.00  $1,187.05  $3,573.95
#
# [621 rows x 9 columns]

# %%
merge
# Out:
# 0          Day of the Week Bill Count    Voids Gross Sales Discounts  \
# Date
# 2020-01-01       Wednesday         67   $52.00   $3,687.00    $51.00
# 2020-01-02        Thursday         57   $55.00   $3,171.00     $0.00
# 2020-01-03          Friday         78   $97.50   $4,416.00     $0.00
# 2020-01-04        Saturday        132  $312.00   $6,946.00    $38.50
# 2020-01-05          Sunday        103   $82.00   $5,821.00     $0.00
# ...                    ...        ...      ...         ...       ...
# 2018-12-27        Thursday         76   $89.00   $4,706.00     $6.60
# 2018-12-28          Friday         82  $100.00   $4,895.00    $10.00
# 2018-12-29        Saturday        111  $124.00   $6,307.00     $0.00
# 2018-12-30          Sunday         94  $227.00   $5,393.00    $10.10
# 2018-12-31          Monday         72  $123.00   $4,845.00     $0.00
#
# 0           Net Sales Menu Item Cost Labor Cost     Margin
# Date
# 2020-01-01  $3,636.00         $36.00  $1,166.20  $2,433.80
# 2020-01-02  $3,171.00          $0.00  $1,002.53  $2,168.47
# 2020-01-03  $4,416.00        $154.00  $1,413.91  $2,848.09
# 2020-01-04  $6,907.50         $24.00  $1,697.33  $5,186.17
# 2020-01-05  $5,821.00         $58.00  $1,514.09  $4,248.91
# ...               ...            ...        ...        ...
# 2018-12-27  $4,699.40        $114.00    $696.53  $3,888.87
# 2018-12-28  $4,885.00         $72.00    $833.36  $3,979.64
# 2018-12-29  $6,307.00        $212.00  $1,244.73  $4,850.27
# 2018-12-30  $5,382.90         $48.00  $1,142.10  $4,192.80
# 2018-12-31  $4,845.00         $84.00  $1,187.05  $3,573.95
#
# [621 rows x 9 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %%
t = ["Voids", "Gross Sales", "Discounts", "Net Sales", "Menu Item Cost", "Labor Cost", "Margin"]

# %%
merge[t] = merge[t].replace({'\$': '', ',': ''}, regex=True).astype(float)

# %%
merge["Bill Count"] = merge["Bill Count"].astype(int)

# %%
merge = pd.concat([merge, pd.get_dummies(merge['Day of the Week'])], axis=1)

# %%
merge.drop('Day of the Week', axis = 1, inplace = True)

# %%
merge.sort_index(inplace = True)

# %% [markdown]
# ### Visualizing Feature Distributions

# %%
merge["Gross Sales"].plot(kind = "hist")

# %%
x_cols = ["Voids", "Discounts", "Net Sales", "Menu Item Cost", "Labor Cost", "Margin", "Bill Count"]

# %%
merge[x_cols].hist(figsize=(15, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12f04ea90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12f03e1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12efee350>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12f14aad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12f180dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12f1b3890>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12f1efcd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12f2228d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12f22d410>]],
#       dtype=object)

# %%
cols = ["Voids", "Discounts","Menu Item Cost", "Labor Cost", "Bill Count"]

# %%
weekly_sales_differenced_once = merge[3::7].diff(1)

# %%
weekly_sales_differenced_once["Gross Sales"].plot(kind = "hist")

# %%
weekly_sales_differenced_once[cols].hist(figsize=(15, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12f4c7ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12f87da10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12f8b1e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12f99d650>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12f9cee50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12fa11690>]],
#       dtype=object)

# %% [markdown]
# ### Exploring the Financial Quarterly Trends

# %% [markdown]
# #### Q3 2018 -- July 1, 2018 to September 30, 2018

# %%
third_q_2018 = merge[30:122:]

# %%
third_q_2018.describe()
# Out:
#        Bill Count       Voids  Gross Sales   Discounts    Net Sales  \
# count   92.000000   92.000000    92.000000   92.000000    92.000000
# mean    91.673913  146.065217  4718.968261   41.383043  4677.585217
# std     28.647194   85.592673  1487.193970   50.105473  1485.076127
# min     41.000000   12.000000  2457.000000    0.000000  2457.000000
# 25%     70.750000   81.000000  3419.757500    0.000000  3415.757500
# 50%     88.000000  134.000000  4581.000000   20.000000  4538.000000
# 75%    111.000000  205.250000  5912.000000   66.250000  5872.437500
# max    192.000000  386.000000  9567.000000  213.250000  9567.000000
#
#        Menu Item Cost   Labor Cost       Margin     Friday     Monday  \
# count       92.000000    92.000000    92.000000  92.000000  92.000000
# mean         7.956522  1081.670543  3587.958152   0.141304   0.141304
# std         26.041350   239.955602  1350.993801   0.350244   0.350244
# min          0.000000   674.000000  1042.870000   0.000000   0.000000
# 25%          0.000000   905.157500  2558.672500   0.000000   0.000000
# 50%          0.000000  1041.255000  3471.680000   0.000000   0.000000
# 75%          0.000000  1200.527500  4660.465000   0.000000   0.000000
# max        144.000000  1870.660000  7696.340000   1.000000   1.000000
#
#         Saturday     Sunday   Thursday    Tuesday  Wednesday
# count  92.000000  92.000000  92.000000  92.000000  92.000000
# mean    0.141304   0.152174   0.141304   0.141304   0.141304
# std     0.350244   0.361158   0.350244   0.350244   0.350244
# min     0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.000000   0.000000   0.000000   0.000000   0.000000
# 50%     0.000000   0.000000   0.000000   0.000000   0.000000
# 75%     0.000000   0.000000   0.000000   0.000000   0.000000
# max     1.000000   1.000000   1.000000   1.000000   1.000000

# %%
third_q_2018["Gross Sales"].hist(figsize=(5, 5))

# %%
third_q_2018[cols].hist(figsize=(15, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12fc40450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x130025a90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12ff60d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1300c0950>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1300fbc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13012e890>]],
#       dtype=object)

# %% [markdown]
# #### Q4 2018 -- October 1, 2018 to December 31, 2018

# %%
fourth_q_2018 = merge[122:212:]

# %%
fourth_q_2018["Gross Sales"].hist(figsize=(5, 5))

# %%
fourth_q_2018[cols].hist(figsize=(15, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12fc4f550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1306c0bd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1307e9fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13081ccd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13085dfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x130894c10>]],
#       dtype=object)

# %% [markdown]
# #### Q1 2019 -- January 1, 2019 to March 31, 2019

# %%
first_q_2019 = merge[213:302:]

# %%
first_q_2019.describe()
# Out:
#        Bill Count       Voids  Gross Sales   Discounts    Net Sales  \
# count   89.000000   89.000000    89.000000   89.000000    89.000000
# mean    77.011236   81.415843  4099.816180   50.739438  4049.076742
# std     34.268159   73.039091  1941.617473   69.163225  1915.557537
# min     26.000000    0.000000  1478.000000    0.000000  1341.500000
# 25%     51.000000   23.000000  2623.000000    0.000000  2623.000000
# 50%     70.000000   68.000000  3544.000000   21.000000  3542.450000
# 75%     99.000000  121.000000  5334.000000   80.000000  5227.000000
# max    183.000000  320.000000  9887.000000  344.500000  9707.500000
#
#        Menu Item Cost   Labor Cost       Margin     Friday     Monday  \
# count       89.000000    89.000000    89.000000  89.000000  89.000000
# mean       132.911124  1044.136067  2872.029551   0.146067   0.134831
# std        126.664166   274.400774  1690.107864   0.355175   0.343479
# min          0.000000   588.870000   504.500000   0.000000   0.000000
# 25%         36.000000   825.000000  1632.340000   0.000000   0.000000
# 50%         96.000000  1007.450000  2346.040000   0.000000   0.000000
# 75%        198.650000  1202.600000  4021.060000   0.000000   0.000000
# max        750.000000  1778.150000  8290.510000   1.000000   1.000000
#
#         Saturday     Sunday   Thursday    Tuesday  Wednesday
# count  89.000000  89.000000  89.000000  89.000000  89.000000
# mean    0.146067   0.134831   0.146067   0.146067   0.146067
# std     0.355175   0.343479   0.355175   0.355175   0.355175
# min     0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.000000   0.000000   0.000000   0.000000   0.000000
# 50%     0.000000   0.000000   0.000000   0.000000   0.000000
# 75%     0.000000   0.000000   0.000000   0.000000   0.000000
# max     1.000000   1.000000   1.000000   1.000000   1.000000

# %%
first_q_2019["Gross Sales"].hist(figsize=(5, 5))

# %%
first_q_2019[cols].hist(figsize=(15, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x130a71390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x130dd5e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x130e0ba50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x130f38d50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x130f6fa50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x130faed90>]],
#       dtype=object)

# %% [markdown]
# #### Q2 2019 -- April 1, 2019 to June 30, 2019

# %%
second_q_2019 = merge[303:394:]

# %%
second_q_2019.describe()
# Out:
#        Bill Count       Voids   Gross Sales   Discounts     Net Sales  \
# count   91.000000   91.000000     91.000000   91.000000     91.000000
# mean    90.021978  146.552637   4849.107253   86.032527   4763.074725
# std     34.418980  113.184222   1856.418381   82.334550   1846.820106
# min     40.000000    0.000000   1798.000000    0.000000   1798.000000
# 25%     62.000000   63.000000   3473.500000   24.500000   3340.250000
# 50%     85.000000  122.000000   4426.810000   55.350000   4426.810000
# 75%    113.000000  201.000000   6046.625000  134.250000   5966.145000
# max    211.000000  596.000000  10946.000000  401.000000  10861.500000
#
#        Menu Item Cost   Labor Cost       Margin     Friday     Monday  \
# count       91.000000    91.000000    91.000000  91.000000  91.000000
# mean       141.406593  1084.142088  3537.526044   0.142857   0.142857
# std        155.656172   326.406251  1566.872155   0.351866   0.351866
# min          0.000000   548.100000  1225.900000   0.000000   0.000000
# 25%         48.000000   839.110000  2471.560000   0.000000   0.000000
# 50%         96.000000  1060.310000  3128.720000   0.000000   0.000000
# 75%        188.000000  1260.675000  4478.135000   0.000000   0.000000
# max        888.000000  1992.760000  8467.980000   1.000000   1.000000
#
#         Saturday     Sunday   Thursday    Tuesday  Wednesday
# count  91.000000  91.000000  91.000000  91.000000  91.000000
# mean    0.142857   0.142857   0.142857   0.142857   0.142857
# std     0.351866   0.351866   0.351866   0.351866   0.351866
# min     0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.000000   0.000000   0.000000   0.000000   0.000000
# 50%     0.000000   0.000000   0.000000   0.000000   0.000000
# 75%     0.000000   0.000000   0.000000   0.000000   0.000000
# max     1.000000   1.000000   1.000000   1.000000   1.000000

# %%
second_q_2019["Gross Sales"].hist(figsize=(5, 5))

# %%
first_q_2019[cols].hist(figsize=(15, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x131572690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1314f6e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13152d950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x131656c50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13168e950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1316ccc90>]],
#       dtype=object)

# %% [markdown]
# #### Q3 2019 -- July 1, 2019 to September 30, 2019

# %%
third_q_2019 = merge[394:486:]

# %%
third_q_2019.describe()
# Out:
#        Bill Count       Voids  Gross Sales   Discounts    Net Sales  \
# count   92.000000   92.000000    92.000000   92.000000    92.000000
# mean    83.434783  133.181304  4378.946848   57.735326  4321.211630
# std     25.943431   88.517944  1424.607532   51.325948  1422.973153
# min     33.000000    0.000000  1537.000000    0.000000  1490.250000
# 25%     67.250000   63.875000  3474.125000   20.312500  3388.250000
# 50%     78.500000  114.000000  4139.665000   44.750000  4060.650000
# 75%     96.500000  190.500000  5198.875000   77.375000  5133.925000
# max    156.000000  347.000000  8751.500000  234.000000  8688.000000
#
#        Menu Item Cost   Labor Cost       Margin     Friday     Monday  \
# count       92.000000    92.000000    92.000000  92.000000  92.000000
# mean       102.695652  1178.853913  3039.662065   0.141304   0.152174
# std        101.595810   240.431315  1273.235361   0.350244   0.361158
# min          0.000000   688.600000   394.080000   0.000000   0.000000
# 25%         36.000000  1022.967500  2273.610000   0.000000   0.000000
# 50%         70.000000  1151.285000  2882.055000   0.000000   0.000000
# 75%        146.500000  1343.625000  3740.257500   0.000000   0.000000
# max        598.000000  1819.920000  6997.690000   1.000000   1.000000
#
#         Saturday     Sunday   Thursday    Tuesday  Wednesday
# count  92.000000  92.000000  92.000000  92.000000  92.000000
# mean    0.141304   0.141304   0.141304   0.141304   0.141304
# std     0.350244   0.350244   0.350244   0.350244   0.350244
# min     0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.000000   0.000000   0.000000   0.000000   0.000000
# 50%     0.000000   0.000000   0.000000   0.000000   0.000000
# 75%     0.000000   0.000000   0.000000   0.000000   0.000000
# max     1.000000   1.000000   1.000000   1.000000   1.000000

# %%
third_q_2019["Gross Sales"].hist(figsize=(5, 5))

# %%
third_q_2019[cols].hist( figsize=(15, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x131851dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x131cbbc10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x131c30810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x131d4efd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x131d8b810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x131dbcf90>]],
#       dtype=object)

# %% [markdown]
# #####  Q3 2019 Stats VS Q3 2018 Stats

# %%
third_q_2019.describe() - third_q_2018.describe()
# Out:
#        Bill Count      Voids  Gross Sales  Discounts   Net Sales  \
# count    0.000000   0.000000     0.000000   0.000000    0.000000
# mean    -8.239130 -12.883913  -340.021413  16.352283 -356.373587
# std     -2.703763   2.925272   -62.586438   1.220476  -62.102974
# min     -8.000000 -12.000000  -920.000000   0.000000 -966.750000
# 25%     -3.500000 -17.125000    54.367500  20.312500  -27.507500
# 50%     -9.500000 -20.000000  -441.335000  24.750000 -477.350000
# 75%    -14.500000 -14.750000  -713.125000  11.125000 -738.512500
# max    -36.000000 -39.000000  -815.500000  20.750000 -879.000000
#
#        Menu Item Cost  Labor Cost      Margin  Friday    Monday  Saturday  \
# count        0.000000    0.000000    0.000000     0.0  0.000000       0.0
# mean        94.739130   97.183370 -548.296087     0.0  0.010870       0.0
# std         75.554459    0.475713  -77.758440     0.0  0.010914       0.0
# min          0.000000   14.600000 -648.790000     0.0  0.000000       0.0
# 25%         36.000000  117.810000 -285.062500     0.0  0.000000       0.0
# 50%         70.000000  110.030000 -589.625000     0.0  0.000000       0.0
# 75%        146.500000  143.097500 -920.207500     0.0  0.000000       0.0
# max        454.000000  -50.740000 -698.650000     0.0  0.000000       0.0
#
#          Sunday  Thursday  Tuesday  Wednesday
# count  0.000000       0.0      0.0        0.0
# mean  -0.010870       0.0      0.0        0.0
# std   -0.010914       0.0      0.0        0.0
# min    0.000000       0.0      0.0        0.0
# 25%    0.000000       0.0      0.0        0.0
# 50%    0.000000       0.0      0.0        0.0
# 75%    0.000000       0.0      0.0        0.0
# max    0.000000       0.0      0.0        0.0

# %% [markdown]
# #### Q4 2019 -- October 1, 2019 to December 31, 2019

# %%
fourth_q_2019 = merge[486:574:]

# %%
fourth_q_2019.describe()
# Out:
#        Bill Count        Voids  Gross Sales   Discounts    Net Sales  \
# count   88.000000    88.000000    88.000000   88.000000    88.000000
# mean    80.693182   209.128750  4527.290795   24.400000  4502.890795
# std     31.768689   652.173076  1834.534033   27.269334  1831.460135
# min     22.000000     0.000000  1057.000000    0.000000  1057.000000
# 25%     59.000000    54.500000  3131.000000    2.625000  3077.500000
# 50%     74.000000   114.000000  4084.335000   15.500000  4068.835000
# 75%     96.250000   180.250000  5529.500000   33.275000  5506.250000
# max    175.000000  6123.000000  9298.000000  124.000000  9255.500000
#
#        Menu Item Cost   Labor Cost       Margin     Friday     Monday  \
# count       88.000000    88.000000    88.000000  88.000000  88.000000
# mean        92.272727  1185.214205  3225.403864   0.147727   0.136364
# std        113.970023   238.125966  1688.765198   0.356863   0.345141
# min          0.000000   556.130000    32.930000   0.000000   0.000000
# 25%         12.000000  1022.922500  1949.360000   0.000000   0.000000
# 50%         54.000000  1183.780000  2937.315000   0.000000   0.000000
# 75%        131.000000  1337.265000  4281.610000   0.000000   0.000000
# max        618.000000  1726.390000  7917.760000   1.000000   1.000000
#
#         Saturday     Sunday   Thursday    Tuesday  Wednesday
# count  88.000000  88.000000  88.000000  88.000000  88.000000
# mean    0.147727   0.147727   0.136364   0.147727   0.136364
# std     0.356863   0.356863   0.345141   0.356863   0.345141
# min     0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.000000   0.000000   0.000000   0.000000   0.000000
# 50%     0.000000   0.000000   0.000000   0.000000   0.000000
# 75%     0.000000   0.000000   0.000000   0.000000   0.000000
# max     1.000000   1.000000   1.000000   1.000000   1.000000

# %%
fourth_q_2019["Gross Sales"].hist(figsize=(5, 5))

# %%
fourth_q_2019[cols].hist(figsize=(15, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x131faa510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1323e5610>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x132359dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132487610>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1324bde10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1324fd650>]],
#       dtype=object)

# %% [markdown]
# ##### Q4 2019 Stats VS Q4 2018 Stats

# %%
fourth_q_2019.describe() - fourth_q_2018.describe()
# Out:
#        Bill Count        Voids  Gross Sales   Discounts   Net Sales  \
# count   -2.000000    -2.000000    -2.000000   -2.000000   -2.000000
# mean    -1.240152    64.395417    86.707018  -13.234000   99.941018
# std      1.701797   558.839579   233.546266  -29.880628  240.628783
# min      1.000000     0.000000   -11.000000    0.000000  -11.000000
# 25%     -0.250000   -23.750000    31.492500    2.625000   36.500000
# 50%     -1.000000   -22.000000  -201.665000    5.450000 -154.915000
# 75%     -7.500000   -12.000000   142.500000  -22.725000  136.825000
# max     21.000000  5605.000000   343.990000 -122.000000  385.990000
#
#        Menu Item Cost  Labor Cost      Margin    Friday    Monday  Saturday  \
# count       -2.000000   -2.000000   -2.000000 -2.000000 -2.000000 -2.000000
# mean       -29.360606  126.468316    2.833308  0.003283 -0.008081  0.003283
# std         -1.540223  -32.255429  320.831328  0.003354 -0.008368  0.003354
# min          0.000000  -17.660000 -140.340000  0.000000  0.000000  0.000000
# 25%        -36.000000  180.850000 -235.110000  0.000000  0.000000  0.000000
# 50%        -42.000000  189.980000 -147.170000  0.000000  0.000000  0.000000
# 75%         -8.500000   69.165000  288.927500  0.000000  0.000000  0.000000
# max         66.000000   -9.890000  670.280000  0.000000  0.000000  0.000000
#
#          Sunday  Thursday   Tuesday  Wednesday
# count -2.000000 -2.000000 -2.000000  -2.000000
# mean   0.003283 -0.008081  0.014394  -0.008081
# std    0.003354 -0.008368  0.015024  -0.008368
# min    0.000000  0.000000  0.000000   0.000000
# 25%    0.000000  0.000000  0.000000   0.000000
# 50%    0.000000  0.000000  0.000000   0.000000
# 75%    0.000000  0.000000  0.000000   0.000000
# max    0.000000  0.000000  0.000000   0.000000

# %% [markdown]
# ### Exploring Quarterly Stats

# %% [markdown]
# #### Q2 2019 Stats VS Q1 2019 Stats

# %%
second_q_2019.describe() - first_q_2019.describe()
# Out:
#        Bill Count       Voids  Gross Sales  Discounts    Net Sales  \
# count    2.000000    2.000000     2.000000   2.000000     2.000000
# mean    13.010742   65.136795   749.291073  35.293089   713.997984
# std      0.150821   40.145131   -85.199092  13.171325   -68.737431
# min     14.000000    0.000000   320.000000   0.000000   456.500000
# 25%     11.000000   40.000000   850.500000  24.500000   717.250000
# 50%     15.000000   54.000000   882.810000  34.350000   884.360000
# 75%     14.000000   80.000000   712.625000  54.250000   739.145000
# max     28.000000  276.000000  1059.000000  56.500000  1154.000000
#
#        Menu Item Cost  Labor Cost      Margin    Friday    Monday  Saturday  \
# count        2.000000    2.000000    2.000000  2.000000  2.000000  2.000000
# mean         8.495470   40.006020  665.496493 -0.003210  0.008026 -0.003210
# std         28.992006   52.005477 -123.235709 -0.003309  0.008387 -0.003309
# min          0.000000  -40.770000  721.400000  0.000000  0.000000  0.000000
# 25%         12.000000   14.110000  839.220000  0.000000  0.000000  0.000000
# 50%          0.000000   52.860000  782.680000  0.000000  0.000000  0.000000
# 75%        -10.650000   58.075000  457.075000  0.000000  0.000000  0.000000
# max        138.000000  214.610000  177.470000  0.000000  0.000000  0.000000
#
#          Sunday  Thursday   Tuesday  Wednesday
# count  2.000000  2.000000  2.000000   2.000000
# mean   0.008026 -0.003210 -0.003210  -0.003210
# std    0.008387 -0.003309 -0.003309  -0.003309
# min    0.000000  0.000000  0.000000   0.000000
# 25%    0.000000  0.000000  0.000000   0.000000
# 50%    0.000000  0.000000  0.000000   0.000000
# 75%    0.000000  0.000000  0.000000   0.000000
# max    0.000000  0.000000  0.000000   0.000000

# %% [markdown]
# #### Q2 2019 Stats VS Q1 2019 Stats

# %%
second_q_2019.describe() - first_q_2019.describe()
# Out:
#        Bill Count       Voids  Gross Sales  Discounts    Net Sales  \
# count    2.000000    2.000000     2.000000   2.000000     2.000000
# mean    13.010742   65.136795   749.291073  35.293089   713.997984
# std      0.150821   40.145131   -85.199092  13.171325   -68.737431
# min     14.000000    0.000000   320.000000   0.000000   456.500000
# 25%     11.000000   40.000000   850.500000  24.500000   717.250000
# 50%     15.000000   54.000000   882.810000  34.350000   884.360000
# 75%     14.000000   80.000000   712.625000  54.250000   739.145000
# max     28.000000  276.000000  1059.000000  56.500000  1154.000000
#
#        Menu Item Cost  Labor Cost      Margin    Friday    Monday  Saturday  \
# count        2.000000    2.000000    2.000000  2.000000  2.000000  2.000000
# mean         8.495470   40.006020  665.496493 -0.003210  0.008026 -0.003210
# std         28.992006   52.005477 -123.235709 -0.003309  0.008387 -0.003309
# min          0.000000  -40.770000  721.400000  0.000000  0.000000  0.000000
# 25%         12.000000   14.110000  839.220000  0.000000  0.000000  0.000000
# 50%          0.000000   52.860000  782.680000  0.000000  0.000000  0.000000
# 75%        -10.650000   58.075000  457.075000  0.000000  0.000000  0.000000
# max        138.000000  214.610000  177.470000  0.000000  0.000000  0.000000
#
#          Sunday  Thursday   Tuesday  Wednesday
# count  2.000000  2.000000  2.000000   2.000000
# mean   0.008026 -0.003210 -0.003210  -0.003210
# std    0.008387 -0.003309 -0.003309  -0.003309
# min    0.000000  0.000000  0.000000   0.000000
# 25%    0.000000  0.000000  0.000000   0.000000
# 50%    0.000000  0.000000  0.000000   0.000000
# 75%    0.000000  0.000000  0.000000   0.000000
# max    0.000000  0.000000  0.000000   0.000000

# %% [markdown]
# ### Daily Gross Sales Correlation Heatmap

# %%
def heatmap_numeric_w_dependent_variable(df, dependent_variable):
    plt.figure(figsize=(12, 12))
    graph = sns.heatmap(df.corr()[[dependent_variable]].sort_values(by=dependent_variable), 
                    annot=True, 
                    cmap='coolwarm', 
                    vmin=-1,
                    vmax=1) 
    return graph

# %%
heatmap_numeric_w_dependent_variable(merge, "Gross Sales")

# %%
drop_corr_cols = ["Net Sales", "Margin"]

# %%
merge.drop(drop_corr_cols, axis = 1, inplace = True)

# %% [markdown]
# ### Daily Gross Sales (in thousands)

# %%
def plot_series(df, cols=None, title='Title', xlab=None, ylab=None, steps=1):
    
    # Set figure size to be (18, 9).
    plt.figure(figsize=(18,9))
    
    # Iterate through each column name.
    for col in cols:
            
        # Generate a line plot of the column name.
        # You only have to specify Y, since our
        # index will be a datetime index.
        plt.plot(df[col])
        
    # Generate title and labels.
    plt.title(title, fontsize=26)
    plt.xlabel(xlab, fontsize=20)
    plt.ylabel(ylab, fontsize=20)
    
    # Enlarge tick marks.
    plt.yticks(fontsize=18)
    plt.xticks(df.index[0::steps], fontsize=18);

# %%
plot_series(merge, ['Gross Sales'], title = "Daily Sales(in thousands with quarterly steps)", steps=90)

# %%
plot_series(weekly_sales_differenced_once, ['Gross Sales'], title = "Weekly Sales Differenced Once (in thousands)", steps=30)

# %%
weekly_sales_differenced_once.describe()
# Out:
#        Bill Count       Voids  Gross Sales  Discounts    Net Sales  \
# count   88.000000   88.000000    88.000000   88.00000    88.000000
# mean     0.306818    1.340909    41.670455    0.00000    41.670455
# std     22.678339  131.173330  1104.286149   69.71733  1095.839621
# min    -76.000000 -439.000000 -3391.000000 -228.00000 -3369.000000
# 25%    -12.000000  -71.750000  -601.002500  -27.08750  -629.375000
# 50%     -1.500000    4.500000    10.250000    0.00000   -36.750000
# 75%     14.250000   54.500000   836.850000   31.00000   831.250000
# max     55.000000  360.000000  2860.500000  246.00000  2857.000000
#
#        Menu Item Cost   Labor Cost       Margin  Friday      Monday  \
# count       88.000000    88.000000    88.000000    88.0   88.000000
# mean         1.068182    12.444886    28.157386     0.0    2.897727
# std        135.342056   255.899600  1093.335385     0.0   27.183091
# min       -342.000000  -593.960000 -3335.110000     0.0    0.000000
# 25%        -48.500000  -121.965000  -654.427500     0.0    0.000000
# 50%          0.000000    -5.280000   -50.730000     0.0    0.000000
# 75%         46.717500   149.237500   673.125000     0.0    0.000000
# max        430.000000  1024.610000  2679.000000     0.0  255.000000
#
#         Saturday  Sunday  Thursday     Tuesday  Wednesday
# count  88.000000    88.0      88.0   88.000000       88.0
# mean    0.011364     0.0       0.0    2.909091        0.0
# std     0.106600     0.0       0.0   27.182075        0.0
# min     0.000000     0.0       0.0    0.000000        0.0
# 25%     0.000000     0.0       0.0    0.000000        0.0
# 50%     0.000000     0.0       0.0    0.000000        0.0
# 75%     0.000000     0.0       0.0    0.000000        0.0
# max     1.000000     0.0       0.0  255.000000        0.0

# %% [markdown]
# ## ACF & PACF Plots

# %%
# Generate plot.
plot_acf(merge['Gross Sales'].dropna(), lags=20);

# %%
plot_pacf(merge['Gross Sales'].dropna(), lags=20);

# %% [markdown]
# ## ADF Test for Stationarity

# %%
# Run ADF test on original (non-differenced!) data.
adfuller(merge['Gross Sales'])
# Out:
# (-4.413893331869135,
#  0.00028047084978728866,
#  14,
#  606,
#  {'1%': -3.4411869900487906,
#   '5%': -2.866321181236609,
#   '10%': -2.569316262893616},
#  9994.277564875969)

# %%
# Code written by Joseph Nelson.
def interpret_dftest(dftest):
    dfoutput = pd.Series(dftest[0:2], index=['Test Statistic','p-value'])
    return dfoutput

# %%
# Run ADF test on original (non-differenced!) data.
interpret_dftest(adfuller(merge['Gross Sales']))
# Out:
# Test Statistic   -4.413893
# p-value           0.000280
# dtype: float64

# %% [markdown]
# ## Model Prep

# %%
merge.index = pd.DatetimeIndex(merge.index).to_period('d')

# %%
621 *.35
# Out:
# 217.35

# %%
X_test_exog = merge.iloc[:217,:]

# %%
X_train_exog = merge.iloc[:404:]

# %%
X_train = X_train_exog.drop("Gross Sales", axis = 1)

# %%
X_test = X_test_exog.drop("Gross Sales", axis = 1)

# %%
y_train = X_train_exog['Gross Sales']

# %%
y_test = X_test_exog['Gross Sales']

# %% [markdown]
# ## Model Selection with AIC:

# %%
# Define the p, d and q parameters to take any value between 0 and 2
p = d = q = range(0, 2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = SARIMAX(y_train,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('SARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
            
            
# #  #best params
# Out:
# SARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:7989.702069938601
# SARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:7463.397401632603
# SARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:7274.642726553804
# SARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:6860.079348177234
# SARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:7260.1466576418225
# SARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:7091.125153149895
# SARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:7017.342987578313
# SARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:6766.319566697315
# SARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:7747.191675860346
# SARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:7446.007105501146
# SARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:7127.405912019101
# SARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:6648.291104602344
# SARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:7454.961710114084
# SARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:6901.881474326379
# SARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:6890.4557620756295
# SARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:6644.501807486621
# SARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:7178.999621659536
# SARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:6924.19195328061
# SARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:7327.7993982389535
# SARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:6782.68985590589
# SARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:6959.516690804332
# SARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:6921.1615695424325
# SARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:7015.449734101682
# SARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:6759.876564134223
# SARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:7161.5450927704005
# SARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:6902.575757343906
# SARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:7306.022383940674
# SARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:6729.183767808957
# SARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:6961.992197867419
# SARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:6906.002801946941
# SARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:6999.554391869891
# SARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:6714.159320700763
# SARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:7183.610677210684
# SARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:6935.471941622609
# SARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:7208.585931684211
# SARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:6689.99260886343
# SARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:6953.0316724334
# SARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:6936.091534031353
# SARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:6904.778939236625
# SARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:6676.579781777335
# SARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:7163.413472799488
# SARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:6919.496223503946
# SARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:7127.952233467888
# SARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:6644.637729246404
# SARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:6953.462024202652
# SARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:6897.328768293361
# SARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:6844.157840445419
# SARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:6638.187697591222
# SARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:7180.399861672083
# SARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:6923.40603971471
# SARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:7328.5643412152085
# SARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:6783.995498126929
# SARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:6945.135251718382
# SARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:6923.7648846994725
# SARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:6988.240143893414
# SARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:6761.455490694568
# SARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:7056.372439225351
# SARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:6782.579217565895
# SARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:7199.812336794306
# SARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:6656.4930072602965
# SARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:6846.856762355539
# SARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:6810.778464076862
# SARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:7000.784516097105
# SARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:6637.091345311467

# %% [markdown]
# ## Modeling

# %%
sarima = SARIMAX(endog = y_train,# inout the best params for this model
                 order = (1, 1, 1),              # (p, d, q)
                 seasonal_order = (1, 1, 1, 12),  # (P, D, Q, S)
                 exog = X_train)
# Fit SARIMA model
model = sarima.fit()

# %%
preds = model.predict(start = len(y_train), end = len(y_train) + len(y_test) - 1, exog = X_test)

# %% [markdown]
# - Prepping index for graphing

# %%
y_test.index = y_test.index.to_timestamp()

# %%
y_train.index = y_train.index.to_timestamp()

# %%
preds.index = preds.index.to_timestamp()

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ### Baseline Model

# %%
merge["Gross Sales"].mean()
# Out:
# 4563.761674718196

# %% [markdown]
# ### r2 Metric Score

# %%
metrics.r2_score(y_test, preds)
# Out:
# 0.9131270881192943

# %% [markdown]
# ### RMSE Metric Score

# %%
mse = mean_squared_error(y_test[0:len(y_test)], preds)
mse
# Out:
# 210102.17182728768

# %%
print(f'RMSE SCORE {math.sqrt(mse)}')
# Out:
# RMSE SCORE 458.36903454235176

# %% [markdown]
# ### Residuals Plot

# %%
sns.residplot(preds, y_test)

# %% [markdown]
# ### Sales Predictions SARIMAX Graph

# %%
plt.figure(figsize=(12,6))
plt.plot(y_train, color = 'blue')
plt.plot(y_test, color = 'orange')
plt.plot(preds, color = 'green')
# plt.plot(future_forecast, color = 'black')

plt.title(label = 'Sales Predictions SARIMAX', fontsize=16)
plt.show();

# %% [markdown]
# ## Budget Calculations

# %% [markdown]
# ### The Bible:
#
# ● Total prime less than 60%
#
# ● Food cost 25 to 30%
#
# ● Labor cost BOH 15% to 20%
#
# ● Labor cost FOH 10 to 15%
#
# ● Profitmax15%
#
# ● 7 extreme low. 12% average 15 is excellent

# %%
weekly_preds_sales_total = []
for i in range(0, len(preds), 7):
    chunk = preds[i:i + 7]
    weekly_preds_sales_total.append(chunk.sum())
weekly_preds_sales_total[0]
# Out:
# 37884.259315238625

# %%
for i, total in enumerate(weekly_preds_sales_total, start=1):
    print(f'Week {i}: Predicted Sales: ${round(total)}')
    print(f'Total Prime Cost Less Than: ${round(total*.6,2)}')
    print(f'Food Cost Guidelines: Low = ${round(total*.25,2)} to High = ${round(total*.30,2)}')
    print(f'Labor Cost BOH Guidelines: Low = ${round(total*.15,2)} to high = ${round(total*.20,2)} ')
    print(f'Labor Cost FOH Guidelines: Low = ${round(total*.1,2)} to high = ${round(total*.15,2)}')
    print(f'Total Profit Guidelines: low = ${round(total*.07,2)}, Average = ${round(total*.12,2)} & Excellent = ${round(total*.15,2)}')
    print()
# Out:
# Week 1: Predicted Sales: $37884.0
# Total Prime Cost Less Than: $22730.56
# Food Cost Guidelines: Low = $9471.06 to High = $11365.28
# Labor Cost BOH Guidelines: Low = $5682.64 to high = $7576.85
# Labor Cost FOH Guidelines: Low = $3788.43 to high = $5682.64
# Total Profit Guidelines: low = $2651.9, Average = $4546.11 & Excellent = $5682.64
#
# Week 2: Predicted Sales: $35744.0
# Total Prime Cost Less Than: $21446.3
# Food Cost Guidelines: Low = $8935.96 to High = $10723.15
# Labor Cost BOH Guidelines: Low = $5361.58 to high = $7148.77
# Labor Cost FOH Guidelines: Low = $3574.38 to high = $5361.58
# Total Profit Guidelines: low = $2502.07, Average = $4289.26 & Excellent = $5361.58
#
# Week 3: Predicted Sales: $33998.0
# Total Prime Cost Less Than: $20398.62
# Food Cost Guidelines: Low = $8499.42 to High = $10199.31
# Labor Cost BOH Guidelines: Low = $5099.65 to high = $6799.54
# Labor Cost FOH Guidelines: Low = $3399.77 to high = $5099.65
# Total Profit Guidelines: low = $2379.84, Average = $4079.72 & Excellent = $5099.65
#
# Week 4: Predicted Sales: $36199.0
# Total Prime Cost Less Than: $21719.48
# Food Cost Guidelines: Low = $9049.78 to High = $10859.74
# Labor Cost BOH Guidelines: Low = $5429.87 to high = $7239.83
# Labor Cost FOH Guidelines: Low = $3619.91 to high = $5429.87
# Total Profit Guidelines: low = $2533.94, Average = $4343.9 & Excellent = $5429.87
#
# Week 5: Predicted Sales: $31437.0
# Total Prime Cost Less Than: $18862.12
# Food Cost Guidelines: Low = $7859.22 to High = $9431.06
# Labor Cost BOH Guidelines: Low = $4715.53 to high = $6287.37
# Labor Cost FOH Guidelines: Low = $3143.69 to high = $4715.53
# Total Profit Guidelines: low = $2200.58, Average = $3772.42 & Excellent = $4715.53
#
# Week 6: Predicted Sales: $33606.0
# Total Prime Cost Less Than: $20163.37
# Food Cost Guidelines: Low = $8401.41 to High = $10081.69
# Labor Cost BOH Guidelines: Low = $5040.84 to high = $6721.12
# Labor Cost FOH Guidelines: Low = $3360.56 to high = $5040.84
# Total Profit Guidelines: low = $2352.39, Average = $4032.67 & Excellent = $5040.84
#
# Week 7: Predicted Sales: $35424.0
# Total Prime Cost Less Than: $21254.66
# Food Cost Guidelines: Low = $8856.11 to High = $10627.33
# Labor Cost BOH Guidelines: Low = $5313.67 to high = $7084.89
# Labor Cost FOH Guidelines: Low = $3542.44 to high = $5313.67
# Total Profit Guidelines: low = $2479.71, Average = $4250.93 & Excellent = $5313.67
#
# Week 8: Predicted Sales: $33012.0
# Total Prime Cost Less Than: $19807.11
# Food Cost Guidelines: Low = $8252.96 to High = $9903.55
# Labor Cost BOH Guidelines: Low = $4951.78 to high = $6602.37
# Labor Cost FOH Guidelines: Low = $3301.18 to high = $4951.78
# Total Profit Guidelines: low = $2310.83, Average = $3961.42 & Excellent = $4951.78
#
# Week 9: Predicted Sales: $32839.0
# Total Prime Cost Less Than: $19703.59
# Food Cost Guidelines: Low = $8209.83 to High = $9851.8
# Labor Cost BOH Guidelines: Low = $4925.9 to high = $6567.86
# Labor Cost FOH Guidelines: Low = $3283.93 to high = $4925.9
# Total Profit Guidelines: low = $2298.75, Average = $3940.72 & Excellent = $4925.9
#
# Week 10: Predicted Sales: $33525.0
# Total Prime Cost Less Than: $20114.93
# Food Cost Guidelines: Low = $8381.22 to High = $10057.46
# Labor Cost BOH Guidelines: Low = $5028.73 to high = $6704.98
# Labor Cost FOH Guidelines: Low = $3352.49 to high = $5028.73
# Total Profit Guidelines: low = $2346.74, Average = $4022.99 & Excellent = $5028.73
#
# Week 11: Predicted Sales: $30533.0
# Total Prime Cost Less Than: $18320.06
# Food Cost Guidelines: Low = $7633.36 to High = $9160.03
# Labor Cost BOH Guidelines: Low = $4580.01 to high = $6106.69
# Labor Cost FOH Guidelines: Low = $3053.34 to high = $4580.01
# Total Profit Guidelines: low = $2137.34, Average = $3664.01 & Excellent = $4580.01
#
# Week 12: Predicted Sales: $32364.0
# Total Prime Cost Less Than: $19418.66
# Food Cost Guidelines: Low = $8091.11 to High = $9709.33
# Labor Cost BOH Guidelines: Low = $4854.67 to high = $6472.89
# Labor Cost FOH Guidelines: Low = $3236.44 to high = $4854.67
# Total Profit Guidelines: low = $2265.51, Average = $3883.73 & Excellent = $4854.67
#
# Week 13: Predicted Sales: $35374.0
# Total Prime Cost Less Than: $21224.27
# Food Cost Guidelines: Low = $8843.44 to High = $10612.13
# Labor Cost BOH Guidelines: Low = $5306.07 to high = $7074.76
# Labor Cost FOH Guidelines: Low = $3537.38 to high = $5306.07
# Total Profit Guidelines: low = $2476.16, Average = $4244.85 & Excellent = $5306.07
#
# Week 14: Predicted Sales: $31992.0
# Total Prime Cost Less Than: $19195.02
# Food Cost Guidelines: Low = $7997.92 to High = $9597.51
# Labor Cost BOH Guidelines: Low = $4798.75 to high = $6398.34
# Labor Cost FOH Guidelines: Low = $3199.17 to high = $4798.75
# Total Profit Guidelines: low = $2239.42, Average = $3839.0 & Excellent = $4798.75
#
# Week 15: Predicted Sales: $31740.0
# Total Prime Cost Less Than: $19043.81
# Food Cost Guidelines: Low = $7934.92 to High = $9521.91
# Labor Cost BOH Guidelines: Low = $4760.95 to high = $6347.94
# Labor Cost FOH Guidelines: Low = $3173.97 to high = $4760.95
# Total Profit Guidelines: low = $2221.78, Average = $3808.76 & Excellent = $4760.95
#
# Week 16: Predicted Sales: $37082.0
# Total Prime Cost Less Than: $22249.22
# Food Cost Guidelines: Low = $9270.51 to High = $11124.61
# Labor Cost BOH Guidelines: Low = $5562.31 to high = $7416.41
# Labor Cost FOH Guidelines: Low = $3708.2 to high = $5562.31
# Total Profit Guidelines: low = $2595.74, Average = $4449.84 & Excellent = $5562.31
#
# Week 17: Predicted Sales: $32518.0
# Total Prime Cost Less Than: $19510.51
# Food Cost Guidelines: Low = $8129.38 to High = $9755.25
# Labor Cost BOH Guidelines: Low = $4877.63 to high = $6503.5
# Labor Cost FOH Guidelines: Low = $3251.75 to high = $4877.63
# Total Profit Guidelines: low = $2276.23, Average = $3902.1 & Excellent = $4877.63
#
# Week 18: Predicted Sales: $32138.0
# Total Prime Cost Less Than: $19282.76
# Food Cost Guidelines: Low = $8034.49 to High = $9641.38
# Labor Cost BOH Guidelines: Low = $4820.69 to high = $6427.59
# Labor Cost FOH Guidelines: Low = $3213.79 to high = $4820.69
# Total Profit Guidelines: low = $2249.66, Average = $3856.55 & Excellent = $4820.69
#
# Week 19: Predicted Sales: $30874.0
# Total Prime Cost Less Than: $18524.67
# Food Cost Guidelines: Low = $7718.61 to High = $9262.34
# Labor Cost BOH Guidelines: Low = $4631.17 to high = $6174.89
# Labor Cost FOH Guidelines: Low = $3087.45 to high = $4631.17
# Total Profit Guidelines: low = $2161.21, Average = $3704.93 & Excellent = $4631.17
#
# Week 20: Predicted Sales: $34567.0
# Total Prime Cost Less Than: $20740.29
# Food Cost Guidelines: Low = $8641.79 to High = $10370.14
# Labor Cost BOH Guidelines: Low = $5185.07 to high = $6913.43
# Labor Cost FOH Guidelines: Low = $3456.71 to high = $5185.07
# Total Profit Guidelines: low = $2419.7, Average = $4148.06 & Excellent = $5185.07
#
# Week 21: Predicted Sales: $32307.0
# Total Prime Cost Less Than: $19383.91
# Food Cost Guidelines: Low = $8076.63 to High = $9691.96
# Labor Cost BOH Guidelines: Low = $4845.98 to high = $6461.3
# Labor Cost FOH Guidelines: Low = $3230.65 to high = $4845.98
# Total Profit Guidelines: low = $2261.46, Average = $3876.78 & Excellent = $4845.98
#
# Week 22: Predicted Sales: $32782.0
# Total Prime Cost Less Than: $19668.97
# Food Cost Guidelines: Low = $8195.4 to High = $9834.48
# Labor Cost BOH Guidelines: Low = $4917.24 to high = $6556.32
# Labor Cost FOH Guidelines: Low = $3278.16 to high = $4917.24
# Total Profit Guidelines: low = $2294.71, Average = $3933.79 & Excellent = $4917.24
#
# Week 23: Predicted Sales: $32620.0
# Total Prime Cost Less Than: $19572.29
# Food Cost Guidelines: Low = $8155.12 to High = $9786.15
# Labor Cost BOH Guidelines: Low = $4893.07 to high = $6524.1
# Labor Cost FOH Guidelines: Low = $3262.05 to high = $4893.07
# Total Profit Guidelines: low = $2283.43, Average = $3914.46 & Excellent = $4893.07
#
# Week 24: Predicted Sales: $29139.0
# Total Prime Cost Less Than: $17483.16
# Food Cost Guidelines: Low = $7284.65 to High = $8741.58
# Labor Cost BOH Guidelines: Low = $4370.79 to high = $5827.72
# Labor Cost FOH Guidelines: Low = $2913.86 to high = $4370.79
# Total Profit Guidelines: low = $2039.7, Average = $3496.63 & Excellent = $4370.79
#
# Week 25: Predicted Sales: $31217.0
# Total Prime Cost Less Than: $18730.45
# Food Cost Guidelines: Low = $7804.35 to High = $9365.22
# Labor Cost BOH Guidelines: Low = $4682.61 to high = $6243.48
# Labor Cost FOH Guidelines: Low = $3121.74 to high = $4682.61
# Total Profit Guidelines: low = $2185.22, Average = $3746.09 & Excellent = $4682.61
#
# Week 26: Predicted Sales: $24907.0
# Total Prime Cost Less Than: $14944.02
# Food Cost Guidelines: Low = $6226.68 to High = $7472.01
# Labor Cost BOH Guidelines: Low = $3736.01 to high = $4981.34
# Labor Cost FOH Guidelines: Low = $2490.67 to high = $3736.01
# Total Profit Guidelines: low = $1743.47, Average = $2988.8 & Excellent = $3736.01
#
# Week 27: Predicted Sales: $29893.0
# Total Prime Cost Less Than: $17936.01
# Food Cost Guidelines: Low = $7473.34 to High = $8968.0
# Labor Cost BOH Guidelines: Low = $4484.0 to high = $5978.67
# Labor Cost FOH Guidelines: Low = $2989.33 to high = $4484.0
# Total Profit Guidelines: low = $2092.53, Average = $3587.2 & Excellent = $4484.0
#
# Week 28: Predicted Sales: $29595.0
# Total Prime Cost Less Than: $17757.16
# Food Cost Guidelines: Low = $7398.82 to High = $8878.58
# Labor Cost BOH Guidelines: Low = $4439.29 to high = $5919.05
# Labor Cost FOH Guidelines: Low = $2959.53 to high = $4439.29
# Total Profit Guidelines: low = $2071.67, Average = $3551.43 & Excellent = $4439.29
#
# Week 29: Predicted Sales: $33991.0
# Total Prime Cost Less Than: $20394.47
# Food Cost Guidelines: Low = $8497.7 to High = $10197.24
# Labor Cost BOH Guidelines: Low = $5098.62 to high = $6798.16
# Labor Cost FOH Guidelines: Low = $3399.08 to high = $5098.62
# Total Profit Guidelines: low = $2379.36, Average = $4078.89 & Excellent = $5098.62
#
# Week 30: Predicted Sales: $28369.0
# Total Prime Cost Less Than: $17021.67
# Food Cost Guidelines: Low = $7092.36 to High = $8510.83
# Labor Cost BOH Guidelines: Low = $4255.42 to high = $5673.89
# Labor Cost FOH Guidelines: Low = $2836.94 to high = $4255.42
# Total Profit Guidelines: low = $1985.86, Average = $3404.33 & Excellent = $4255.42
#
# Week 31: Predicted Sales: $26469.0
# Total Prime Cost Less Than: $15881.41
# Food Cost Guidelines: Low = $6617.26 to High = $7940.71
# Labor Cost BOH Guidelines: Low = $3970.35 to high = $5293.8
# Labor Cost FOH Guidelines: Low = $2646.9 to high = $3970.35
# Total Profit Guidelines: low = $1852.83, Average = $3176.28 & Excellent = $3970.35

# %% [markdown]
# ## Conclusion & Reccomendations

# %% [markdown]
# ## References
